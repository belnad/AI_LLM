# %%
# !pip install llama-index llama-index-llms-ollama llama-index-embeddings-huggingface llama-index-readers-web python-dotenv
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: llama-index in ./.conda/lib/python3.12/site-packages (0.12.5)
# Requirement already satisfied: llama-index-llms-ollama in ./.conda/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: llama-index-embeddings-huggingface in ./.conda/lib/python3.12/site-packages (0.4.0)
# Requirement already satisfied: llama-index-readers-web in ./.conda/lib/python3.12/site-packages (0.3.1)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.0 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.5 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.12.5)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.6.3)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.3.10)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in ./.conda/lib/python3.12/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in ./.conda/lib/python3.12/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: ollama>=0.4.3 in ./.conda/lib/python3.12/site-packages (from llama-index-llms-ollama) (0.4.4)
# Requirement already satisfied: huggingface-hub>=0.19.0 in ./.conda/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.27.0)
# Requirement already satisfied: sentence-transformers>=2.6.1 in ./.conda/lib/python3.12/site-packages (from llama-index-embeddings-huggingface) (3.3.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-web) (3.11.10)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-web) (4.12.3)
# Requirement already satisfied: chromedriver-autoinstaller<0.7.0,>=0.6.3 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-web) (0.6.4)
# Requirement already satisfied: html2text<2025.0.0,>=2024.2.26 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-web) (2024.2.26)
# Requirement already satisfied: newspaper3k<0.3.0,>=0.2.8 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-web) (0.2.8)
# Requirement already satisfied: playwright<2.0,>=1.30 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-web) (1.49.1)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-web) (2.32.3)
# Requirement already satisfied: selenium<5.0.0,>=4.17.2 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-web) (4.27.1)
# Requirement already satisfied: spider-client<0.0.28,>=0.0.27 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-web) (0.0.27)
# Requirement already satisfied: urllib3>=1.1.0 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-web) (2.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./.conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->llama-index-readers-web) (1.18.3)
# Requirement already satisfied: soupsieve>1.2 in ./.conda/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-web) (2.6)
# Requirement already satisfied: packaging>=23.1 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from chromedriver-autoinstaller<0.7.0,>=0.6.3->llama-index-readers-web) (24.2)
# Requirement already satisfied: filelock in ./.conda/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.conda/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.10.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.conda/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in ./.conda/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.conda/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: openai>=1.14.0 in ./.conda/lib/python3.12/site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.58.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./.conda/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.5->llama-index) (2.0.36)
# Requirement already satisfied: dataclasses-json in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (1.2.0)
# Requirement already satisfied: httpx in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (3.4.2)
# Requirement already satisfied: numpy in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (11.0.0)
# Requirement already satisfied: pydantic>=2.8.0 in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in ./.conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama-index) (1.17.0)
# Requirement already satisfied: llama-cloud>=0.1.5 in ./.conda/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.6)
# Requirement already satisfied: pandas in ./.conda/lib/python3.12/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in ./.conda/lib/python3.12/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.5.17)
# Requirement already satisfied: cssselect>=0.9.2 in ./.conda/lib/python3.12/site-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (1.2.0)
# Requirement already satisfied: lxml>=3.6.0 in ./.conda/lib/python3.12/site-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (5.3.0)
# Requirement already satisfied: feedparser>=5.2.1 in ./.conda/lib/python3.12/site-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in ./.conda/lib/python3.12/site-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (5.1.3)
# Requirement already satisfied: feedfinder2>=0.0.4 in ./.conda/lib/python3.12/site-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in ./.conda/lib/python3.12/site-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (2.9.0.post0)
# Requirement already satisfied: tinysegmenter==0.3 in ./.conda/lib/python3.12/site-packages (from newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (0.3)
# Requirement already satisfied: click in ./.conda/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in ./.conda/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.conda/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: greenlet==3.1.1 in ./.conda/lib/python3.12/site-packages (from playwright<2.0,>=1.30->llama-index-readers-web) (3.1.1)
# Requirement already satisfied: pyee==12.0.0 in ./.conda/lib/python3.12/site-packages (from playwright<2.0,>=1.30->llama-index-readers-web) (12.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->llama-index-readers-web) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->llama-index-readers-web) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->llama-index-readers-web) (2024.12.14)
# Requirement already satisfied: trio~=0.17 in ./.conda/lib/python3.12/site-packages (from selenium<5.0.0,>=4.17.2->llama-index-readers-web) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in ./.conda/lib/python3.12/site-packages (from selenium<5.0.0,>=4.17.2->llama-index-readers-web) (0.11.1)
# Requirement already satisfied: websocket-client~=1.8 in ./.conda/lib/python3.12/site-packages (from selenium<5.0.0,>=4.17.2->llama-index-readers-web) (1.8.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in ./.conda/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.47.1)
# Requirement already satisfied: torch>=1.11.0 in ./.conda/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.5.1)
# Requirement already satisfied: scikit-learn in ./.conda/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: scipy in ./.conda/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.14.1)
# Requirement already satisfied: six in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from feedfinder2>=0.0.4->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (1.17.0)
# Requirement already satisfied: sgmllib3k in ./.conda/lib/python3.12/site-packages (from feedparser>=5.2.1->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (1.0.0)
# Requirement already satisfied: anyio in ./.conda/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama-index) (4.7.0)
# Requirement already satisfied: httpcore==1.* in ./.conda/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama-index) (1.0.7)
# Requirement already satisfied: sniffio in ./.conda/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.conda/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.5->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.conda/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.conda/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.8.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.conda/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.5->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in ./.conda/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.5->llama-index) (2.27.1)
# Requirement already satisfied: requests-file>=1.4 in ./.conda/lib/python3.12/site-packages (from tldextract>=2.0.1->newspaper3k<0.3.0,>=0.2.8->llama-index-readers-web) (2.1.0)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.4)
# Requirement already satisfied: setuptools in ./.conda/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in ./.conda/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.conda/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./.conda/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in ./.conda/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.4.5)
# Requirement already satisfied: sortedcontainers in ./.conda/lib/python3.12/site-packages (from trio~=0.17->selenium<5.0.0,>=4.17.2->llama-index-readers-web) (2.4.0)
# Requirement already satisfied: outcome in ./.conda/lib/python3.12/site-packages (from trio~=0.17->selenium<5.0.0,>=4.17.2->llama-index-readers-web) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in ./.conda/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium<5.0.0,>=4.17.2->llama-index-readers-web) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.conda/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.5->llama-index) (1.0.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in ./.conda/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium<5.0.0,>=4.17.2->llama-index-readers-web) (1.7.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.conda/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.5->llama-index) (3.23.1)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.conda/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.conda/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.0.2)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
from llama_index.core.workflow import (
    StartEvent,
    StopEvent,
    Workflow,
    step,
    Event,
    Context
)
from llama_index.core import Settings, VectorStoreIndex, Document
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.readers.web import BeautifulSoupWebReader
from llama_index.llms.ollama import Ollama

import requests

import json
import urllib.request

from dotenv import load_dotenv
import os

class APIFetchEvent(Event):
    query: str

class StoreEvent(Event):
    query: str

class SummarizingEvent(Event):
    query: str

class ClassifyingEvent(Event):
    query: str

class NewsSummarizer(Workflow):
    Settings.embedding_model = HuggingFaceEmbedding()
    Settings.llm = Ollama(model="llama3.2")

    @step
    async def fetch(self, ctx: Context, ev: StartEvent) -> APIFetchEvent :
        """
        Fetches news articles using the GNews API based on the query and country parameters.
        Saves the articles' metadata to a JSON file and stores the data in the workflow context.

        Args:
            ctx (Context): Workflow context for storing and retrieving data.
            ev (StartEvent): Event containing query parameters (query, country).

        Returns:
            APIFetchEvent: Custom event signaling the completion of the fetch operation.
        """

        # Extract query parameters from the StartEvent
        query = ev.query  # Search keyword for news articles

        # Load API key from the .env file
        load_dotenv()
        apikey = os.environ.get('API_KEY')  # Retrieve the API key for GNews

        # Initialize an empty list to store article data
        articles_data = []

        # Construct the GNews API request URL
        url = f"https://gnews.io/api/v4/search?q={query}&lang=en&country=us&max=5&apikey={apikey}"

        # Send a request to the GNews API
        with urllib.request.urlopen(url) as response:
            # Parse the API response as JSON
            data = json.loads(response.read().decode("utf-8"))
            
            # Extract the articles section from the response
            articles = data.get("articles", [])  # Safely get 'articles' to avoid KeyError

            # Loop through each article and extract relevant fields
            for article in articles:
                articles_data.append({
                    "title": article["title"],                # Article title
                    "description": article["description"],    # Article description
                    "content": article["content"],            # Full article content
                    "url": article["url"],                    # URL to the article
                    "source": article["source"]["name"],      # News source name
                    "publishedAt": article["publishedAt"]     # Publication date
                })

        # Save the fetched articles to a local JSON file for later steps
        json_file_name = "articles.json"
        with open(json_file_name, "w", encoding="utf-8") as json_file:
            json.dump(articles_data, json_file, indent=4, ensure_ascii=False)

        print(f"Data saved to '{json_file_name}' successfully!")

        # Store the fetched articles data in the workflow context for the next steps
        await ctx.set("articles", articles_data)

        # Return a custom APIFetchEvent to signal that fetching was successful
        return APIFetchEvent(query=query)

    @step
    async def store(self, ctx: Context, ev: APIFetchEvent) -> StoreEvent | StopEvent:
        """
        Loads article metadata from a JSON file, fetches full content for each article,
        creates Document objects, generates embeddings, and stores the results in the workflow context.

        Args:
            ctx (Context): Workflow context for storing and retrieving data.
            ev (APIFetchEvent): Event containing the query information.

        Returns:
            StoreEvent: Custom event signaling successful document storage and embedding.
            StopEvent: Stops the workflow in case of failure (e.g., file not found).
        """
        try:
            # Load the articles JSON file containing metadata fetched in the previous step
            with open("articles.json", "r", encoding="utf-8") as json_file:
                articles = json.load(json_file)
                print("Loaded Articles:", articles[:5])  # Print the first 5 articles for verification
        except FileNotFoundError:
            # If the file does not exist, stop the workflow
            print("Error: File not found.")
            return StopEvent()

        print("Fetching article content using BeautifulSoupWebReader...")

        # Initialize the web content reader
        loader = BeautifulSoupWebReader()

        # List to store Document objects
        documents = []

        # Iterate through the articles and fetch their full content
        for i, item in enumerate(articles):
            url = item.get("url", "")  # Extract the URL of the article
            print(f"Processing URL {i + 1}/{len(articles)}: {url}")

            # Default content in case fetching fails
            content = "Content not available"
            # Attempt to load the content using BeautifulSoupWebReader
            content = loader.load_data([url])
            if content:
                content = content[0].text  # Extract the text from the loaded content
            else:
                print(f"Error fetching content from URL: {url}")

            # Create a Document object combining content and metadata
            document = Document(
                text=content,
                metadata={
                    "title": item.get("title", "unknown"),  # Title of the article
                    "description": item.get("description", "general"),  # Description of the article
                    "url": url,  # URL of the article
                    "date": item.get("publishedAt", "unknown"),  # Publication date
                    "source": item.get("source", "unknown"),  # Source name
                },
                metadata_seperator="::",  # Define how metadata pairs are separated
                metadata_template="{key}=>{value}",  # Template for metadata formatting
                text_template="Metadata: {metadata_str}\n-----\nContent: {content}",  # Template for Document text
            )
            documents.append(document)  # Add the Document to the list

        # Save the processed Document objects to the workflow context
        await ctx.set("documents", documents)

        # Generate embeddings for the documents using the configured embedding model
        index = VectorStoreIndex.from_documents(
            documents, 
            embed_model=Settings.embedding_model, 
            show_progress=True  # Display progress while generating embeddings
        )

        print("Embeddings have been generated and stored successfully!")
        print(f"Generated embeddings for {len(documents)} articles.")

        # Save the generated index to the workflow context
        await ctx.set("index", index)

        # Return a custom StoreEvent to signal successful completion
        return StoreEvent(query=ev.query)

    @step
    async def summarize_and_classify(self, ctx: Context, ev: StoreEvent) -> SummarizingEvent:
        """
        Summarizes and classifies the sentiment of articles stored in the context.
        Uses the query engine built from the document embeddings to process each article.

        Args:
            ctx (Context): Workflow context to retrieve and store data.
            ev (StoreEvent): Event signaling that documents are ready for processing.

        Returns:
            SummarizingEvent: Event signaling successful summarization and classification.
        """
        print("--- Summarizing and Classifying Articles...")

        # Retrieve the document index and documents from the workflow context
        index = await ctx.get("index")  # Index containing embeddings and query engine
        documents = await ctx.get("documents")  # List of processed Document objects

        # Create a query engine from the document index for natural language querying
        query_engine = index.as_query_engine()

        # List to store the summarization and sentiment classification results
        results = []

        # Iterate through each document to summarize and classify sentiment
        for i, article in enumerate(documents):
            print(f"Processing article {i + 1}/{len(documents)}: {article.metadata['title']}")

            # Step 1: Generate a summary for the article
            summarize_query = f"Summarize this article: {article.metadata['title']}"
            summary_response = query_engine.query(summarize_query)  # Query the engine for summarization
            summary = summary_response.response.strip()  # Extract and clean the response

            # Step 2: Classify the sentiment of the summary
            classify_prompt = f"""Analyze the following article summary and classify the sentiment 
            as 'Positive', 'Neutral', or 'Negative'. Provide only the sentiment label.

            Summary: {summary}"""
            sentiment_response = query_engine.query(classify_prompt)  # Query for sentiment classification
            sentiment = sentiment_response.response.strip()  # Extract and clean the sentiment label

            # Append the summary and sentiment classification results to the results list
            results.append({
                "title": article.metadata["title"],  # Article title
                "url": article.metadata["url"],      # Article URL
                "summary": summary,                  # Generated summary
                "sentiment": sentiment               # Classified sentiment
            })

        # Store the final results in the workflow context for downstream use
        await ctx.set("results", results)

        # Return an event indicating successful summarization and classification
        return SummarizingEvent(query="Summarized and Classified Articles")

    @step
    async def return_answer(self, ctx: Context, ev: SummarizingEvent) -> StopEvent:
        """
        Final step: Retrieves the summarized and classified results from the workflow context,
        prints them for verification, and returns the results as structured data.

        Args:
            ctx (Context): Workflow context to retrieve the summarized results.
            ev (SummarizingEvent): Event indicating summarization and classification are complete.

        Returns:
            StopEvent: Final event that stops the workflow and outputs the results as structured data.
        """
        # Retrieve the results (list of summaries and sentiments) from the context
        results = await ctx.get("results")

        # Print the final results to the console for verification
        print("Final Results: Summaries and Sentiments")
        for result in results:
            print(f"Title: {result['title']}")  # Print the article title
            print(f"Summary: {result['summary']}")  # Print the article summary
            print(f"Sentiment: {result['sentiment']}")  # Print the sentiment classification
            print("-" * 50)  # Separator for better readability

        # Return a StopEvent containing the results as structured data
        return StopEvent(result={"articles": results})
# Out:
# Running step fetch
# Data saved to 'articles.json' successfully!
# Step fetch produced event APIFetchEvent
# Running step store
# Loaded Articles: [{'title': "PlayStation 5 Pro: Buy Now or Pay Tariffs Later? Here's How Much It Costs to Finance the Gaming Console", 'description': "Trump's tariffs could hike the price tag of the PS5 Pro by 40%. I analyzed the costs and risks of different financing options.", 'content': "Popular imported video game consoles like the PlayStation 5 Pro could become more expensive next year if President-elect Donald Trump's proposed tariffs are implemented -- and gamers are worried.\nDuring his 2024 campaign, Trump promised tariffs of up... [11596 chars]", 'url': 'https://www.cnet.com/personal-finance/credit-cards/playstation-5-pro-buy-now-or-pay-tariffs-later-heres-how-much-it-costs-to-finance-the-gaming-console/', 'source': 'CNET', 'publishedAt': '2024-12-17T15:00:00Z'}, {'title': 'Will Justin Trudeau Resign? How Trump Tariff Threats Led to Chaos', 'description': 'Trudeau\'s leadership is in crisis after the exit of his finance minister, who warned of an impending "tariff war" with the U.S.', 'content': "Reports are circulating that Canadian Prime Minister Justin Trudeau may consider resigning, following the departure of a top cabinet member and ongoing trade tensions with President-elect Donald Trump.\nWhat's New?\nOn Monday, CTV News cited sources sa... [8328 chars]", 'url': 'https://www.newsweek.com/justin-trudeau-resignation-donald-trump-tariffs-2002023', 'source': 'Newsweek', 'publishedAt': '2024-12-17T14:23:27Z'}, {'title': "'Makes little sense': CNN's Jim Sciutto vents about Trump's needling of Canada", 'description': 'President-elect Donald Trump on Monday continued to call Canada\'s Prime Minister Justin Trudeau the country\'s "governor."Wall Street Journal national politics reporter Vivian Salama reported via X: "Trump weighs in on the resignation of Canada’s Finance Minister Christie Freeland amid his threats to...', 'content': 'President-elect Donald Trump on Monday continued to call Canada\'s Prime Minister Justin Trudeau the country\'s "governor."\nWall Street Journal national politics reporter Vivian Salama reported via X: "Trump weighs in on the resignation of Canada’s Fin... [1158 chars]', 'url': 'https://www.rawstory.com/makes-little-sense-cnn-s-jim-sciutto/', 'source': 'Raw Story', 'publishedAt': '2024-12-17T13:36:34Z'}, {'title': 'Calls for Trudeau to resign as exiting Canadian finance minister warns of Trump tariffs', 'description': "Canadian Prime Minister Justin Trudeau quietly defied mounting calls for his resignation on Monday, asking Dominic LeBlanc to serve as finance minister after Chrystia Freeland resigned from the post with a scathing letter that sounded the alarm about U.S. President-elect Donald Trump's threat to imp...", 'content': 'Canadian Prime Minister Justin Trudeau quietly defied mounting calls for his resignation on Monday, asking Dominic LeBlanc to serve as finance minister after Chrystia Freeland resigned from the post with a scathing letter that sounded the alarm about... [6023 chars]', 'url': 'https://www.rawstory.com/calls-for-trudeau-to-resign-as-exiting-canadian-finance-minister-warns-of-trump-tariffs/', 'source': 'Raw Story', 'publishedAt': '2024-12-17T11:43:56Z'}, {'title': 'Alphabet-backed Indian lender files for $171M IPO', 'description': 'Aye Finance, a lender targeting small- and medium-sized businesses in India, is seeking to raise $171 million from its initial public offering, it', 'content': 'Aye Finance, a lender targeting small- and medium-sized businesses in India, is seeking to raise $171 million from its initial public offering, it disclosed in a filing Tuesday.\nThe offering comprises a $104 million fresh share issue and a $67 millio... [1561 chars]', 'url': 'https://techcrunch.com/2024/12/17/aye-finance-ipo/', 'source': 'TechCrunch', 'publishedAt': '2024-12-17T08:07:46Z'}]
# Fetching article content using BeautifulSoupWebReader...
# Processing URL 1/5: https://www.cnet.com/personal-finance/credit-cards/playstation-5-pro-buy-now-or-pay-tariffs-later-heres-how-much-it-costs-to-finance-the-gaming-console/
# Processing URL 2/5: https://www.newsweek.com/justin-trudeau-resignation-donald-trump-tariffs-2002023
# Processing URL 3/5: https://www.rawstory.com/makes-little-sense-cnn-s-jim-sciutto/
# Processing URL 4/5: https://www.rawstory.com/calls-for-trudeau-to-resign-as-exiting-canadian-finance-minister-warns-of-trump-tariffs/
# Processing URL 5/5: https://techcrunch.com/2024/12/17/aye-finance-ipo/
# Parsing nodes: 100%|██████████| 5/5 [00:00<00:00, 302.15it/s]
# Generating embeddings: 100%|██████████| 10/10 [00:00<00:00, 26.41it/s]
# Embeddings have been generated and stored successfully!
# Generated embeddings for 5 articles.
# Step store produced event StoreEvent
# Running step summarize_and_classify
# --- Summarizing and Classifying Articles...
# Processing article 1/5: PlayStation 5 Pro: Buy Now or Pay Tariffs Later? Here's How Much It Costs to Finance the Gaming Console
# Processing article 2/5: Will Justin Trudeau Resign? How Trump Tariff Threats Led to Chaos
# Processing article 3/5: 'Makes little sense': CNN's Jim Sciutto vents about Trump's needling of Canada
# Processing article 4/5: Calls for Trudeau to resign as exiting Canadian finance minister warns of Trump tariffs
# Processing article 5/5: Alphabet-backed Indian lender files for $171M IPO
# Step summarize_and_classify produced event SummarizingEvent
# Running step return_answer
# Final Results: Summaries and Sentiments
# Title: PlayStation 5 Pro: Buy Now or Pay Tariffs Later? Here's How Much It Costs to Finance the Gaming Console
# Summary: The article discusses how President-elect Donald Trump's proposed tariffs could increase the price of imported goods, including gaming consoles like the PlayStation 5 Pro. If implemented, these tariffs could raise the cost of video game consoles by 40% on average. The article analyzes different financing options for buying the PS5 Pro and suggests that using a credit card to finance the purchase can be costly.
#
# The author argues that buying the console now with a credit card and making minimum monthly payments can lead to a lengthy debt cycle, taking over seven years to pay off, with more than double the extra cost from the price hikes. However, if the buyer makes consistent monthly payments towards the balance, they may be able to avoid paying excessive interest.
#
# The article concludes that using a credit card to finance the purchase is not recommended due to the high interest rates and risk of falling into debt. Instead, it suggests considering alternative options, such as waiting until after the tariffs are implemented or exploring 0% APR credit cards for purchases.
# Sentiment: Negative
# --------------------------------------------------
# Title: Will Justin Trudeau Resign? How Trump Tariff Threats Led to Chaos
# Summary: Justin Trudeau's leadership is facing a crisis as his finance minister has resigned. The former finance minister warned of an impending "tariff war" with the U.S., which has led to mounting calls for Trudeau's resignation. Despite this, Trudeau has asked another politician to serve as finance minister and has not indicated any plans to step down.
# Sentiment: Negative
# --------------------------------------------------
# Title: 'Makes little sense': CNN's Jim Sciutto vents about Trump's needling of Canada
# Summary: The article discusses President-elect Donald Trump's criticism of Canada, specifically his repeated calls to Prime Minister Justin Trudeau as the country's "governor." This nickname has been seen as a belittling remark by some. Additionally, there have been reports of tensions between the US and Canada due to trade disputes, including threats from the US side that led to the resignation of Canada's Finance Minister Christie Freeland.
# Sentiment: Negative
# --------------------------------------------------
# Title: Calls for Trudeau to resign as exiting Canadian finance minister warns of Trump tariffs
# Summary: There are calls for Prime Minister Justin Trudeau's resignation due to a warning from his outgoing finance minister. The concern is sparked by US President-elect Donald Trump's threat of tariffs, which has caused significant alarm among politicians. As a result, the situation is leading to chaos and an uncertain future for Trudeau's leadership.
# Sentiment: Negative
# --------------------------------------------------
# Title: Alphabet-backed Indian lender files for $171M IPO
# Summary: Aye Finance, a company that provides loans to small and medium-sized businesses in India, has filed for an initial public offering (IPO) worth $171 million. The IPO includes a fresh share issue of $104 million and a secondary sale by existing investors amounting to $67 million. The funds raised will be used to expand the startup's loan portfolio and strengthen its capital base. Aye Finance is currently valued at around $400 million, operates 499 branches across 22 Indian states, and has assets under management of $588 million as of September.
# Sentiment: Neutral
# --------------------------------------------------
# Step return_answer produced event StopEvent
# {'articles': [{'title': "PlayStation 5 Pro: Buy Now or Pay Tariffs Later? Here's How Much It Costs to Finance the Gaming Console", 'url': 'https://www.cnet.com/personal-finance/credit-cards/playstation-5-pro-buy-now-or-pay-tariffs-later-heres-how-much-it-costs-to-finance-the-gaming-console/', 'summary': "The article discusses how President-elect Donald Trump's proposed tariffs could increase the price of imported goods, including gaming consoles like the PlayStation 5 Pro. If implemented, these tariffs could raise the cost of video game consoles by 40% on average. The article analyzes different financing options for buying the PS5 Pro and suggests that using a credit card to finance the purchase can be costly.\n\nThe author argues that buying the console now with a credit card and making minimum monthly payments can lead to a lengthy debt cycle, taking over seven years to pay off, with more than double the extra cost from the price hikes. However, if the buyer makes consistent monthly payments towards the balance, they may be able to avoid paying excessive interest.\n\nThe article concludes that using a credit card to finance the purchase is not recommended due to the high interest rates and risk of falling into debt. Instead, it suggests considering alternative options, such as waiting until after the tariffs are implemented or exploring 0% APR credit cards for purchases.", 'sentiment': 'Negative'}, {'title': 'Will Justin Trudeau Resign? How Trump Tariff Threats Led to Chaos', 'url': 'https://www.newsweek.com/justin-trudeau-resignation-donald-trump-tariffs-2002023', 'summary': 'Justin Trudeau\'s leadership is facing a crisis as his finance minister has resigned. The former finance minister warned of an impending "tariff war" with the U.S., which has led to mounting calls for Trudeau\'s resignation. Despite this, Trudeau has asked another politician to serve as finance minister and has not indicated any plans to step down.', 'sentiment': 'Negative'}, {'title': "'Makes little sense': CNN's Jim Sciutto vents about Trump's needling of Canada", 'url': 'https://www.rawstory.com/makes-little-sense-cnn-s-jim-sciutto/', 'summary': 'The article discusses President-elect Donald Trump\'s criticism of Canada, specifically his repeated calls to Prime Minister Justin Trudeau as the country\'s "governor." This nickname has been seen as a belittling remark by some. Additionally, there have been reports of tensions between the US and Canada due to trade disputes, including threats from the US side that led to the resignation of Canada\'s Finance Minister Christie Freeland.', 'sentiment': 'Negative'}, {'title': 'Calls for Trudeau to resign as exiting Canadian finance minister warns of Trump tariffs', 'url': 'https://www.rawstory.com/calls-for-trudeau-to-resign-as-exiting-canadian-finance-minister-warns-of-trump-tariffs/', 'summary': "There are calls for Prime Minister Justin Trudeau's resignation due to a warning from his outgoing finance minister. The concern is sparked by US President-elect Donald Trump's threat of tariffs, which has caused significant alarm among politicians. As a result, the situation is leading to chaos and an uncertain future for Trudeau's leadership.", 'sentiment': 'Negative'}, {'title': 'Alphabet-backed Indian lender files for $171M IPO', 'url': 'https://techcrunch.com/2024/12/17/aye-finance-ipo/', 'summary': "Aye Finance, a company that provides loans to small and medium-sized businesses in India, has filed for an initial public offering (IPO) worth $171 million. The IPO includes a fresh share issue of $104 million and a secondary sale by existing investors amounting to $67 million. The funds raised will be used to expand the startup's loan portfolio and strengthen its capital base. Aye Finance is currently valued at around $400 million, operates 499 branches across 22 Indian states, and has assets under management of $588 million as of September.", 'sentiment': 'Neutral'}]}

# %%
# !pip install ipywidgets
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: comm>=0.1.3 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack_data in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/beatrizfcmenezes/.local/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 16.8 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13

# %%
import asyncio
import ipywidgets as widgets
from IPython.display import display, clear_output

# Function to execute the NewsSummarizer workflow
async def run_news_workflow(query, country, output_widget):
    try:
        # Instantiate the workflow
        news_summarizer = NewsSummarizer(timeout=500.0, verbose=True)

        # Run the workflow with inputs
        result = await news_summarizer.run(query=query, country=country)
        articles = result.result["articles"]

        # Display results in the output widget
        with output_widget:
            clear_output()
            print(f"News Articles for Query: '{query}', Country: '{country}'")
            print("-" * 50)
            for article in articles:
                print(f"Title: {article['title']}")
                print(f"Summary: {article['summary']}")
                print(f"Sentiment: {article['sentiment']}")
                print(f"URL: {article['url']}")
                print("-" * 50)
    except Exception as e:
        with output_widget:
            clear_output()
            print(f"An error occurred: {e}")

# UI Widgets
query_input = widgets.Text(description="Query:", placeholder="e.g., finance, tech")
output_area = widgets.Output()
submit_button = widgets.Button(description="Fetch News", button_style='success')

# Event Handler for Button Click
def on_submit_button_clicked(b):
    if not query_input.value:
        with output_area:
            clear_output()
            print("Please provide both a query and a country code.")
    else:
        # Run the async function
        asyncio.create_task(run_news_workflow(query_input.value, output_area))

# Bind button click to the event handler
submit_button.on_click(on_submit_button_clicked)

# Display the UI
display(widgets.VBox([
    widgets.Label("News Summarizer and Sentiment Classifier", style={"font_size": "16px"}),
    query_input,
    submit_button,
    output_area
]))
# Out:
# VBox(children=(Label(value='News Summarizer and Sentiment Classifier', style=LabelStyle(font_size='16px')), Te…
